# %%
import shutil, os
if os.path.exists('/content/project'):
    shutil.rmtree('/content/project')
# !git clone https://github.com/TruongDuyLongPTIT/CTQW-PRO-Quantum-Walk-Based-Metabolite-Disease-Prioritization.git /content/project

# Add src vào Python path
import sys
sys.path.insert(0, '/content/project/src')

# Install dependencies
# !pip install -q torch scikit-learn networkx tqdm
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 517, done.
# remote: Counting objects: 100% (314/314), done.
# remote: Compressing objects: 100% (237/237), done.
# remote: Total 517 (delta 207), reused 154 (delta 74), pack-reused 203 (from 1)
# Receiving objects: 100% (517/517), 1.32 MiB | 15.31 MiB/s, done.
# Resolving deltas: 100% (327/327), done.

# %%
from pathlib import Path
from google.colab import drive

if not Path('/content/drive/MyDrive').exists():
    drive.mount('/content/drive')
else:
    print("Drive đã mount sẵn.")
# Out:
# Mounted at /content/drive

# %%
# !python /content/project/experiments/01_main_results_kegg.py
# Out:
# ============================================================
# STEP 1 — Build graph (KEGG)
# Lấy danh sách pathway chuyển hóa ở người (BRITE br08901 ∩ hsa)...
#   86 pathway (đã loại overview/chemical-structure maps)
# Lấy reaction id theo từng pathway (link/rn/mapNNNNN)...
#     20/86 pathway...
#     40/86 pathway...
#     60/86 pathway...
#     80/86 pathway...
#   4497 reaction id duy nhất (hợp của mọi pathway)
# Lấy EQUATION cho từng reaction (batch 10, get/rn:...+rn:...)...
#     equations: 20/450 batch...
#     equations: 40/450 batch...
#     equations: 60/450 batch...
#     equations: 80/450 batch...
#     equations: 100/450 batch...
#     equations: 120/450 batch...
#     equations: 140/450 batch...
#     equations: 160/450 batch...
#     equations: 180/450 batch...
#     equations: 200/450 batch...
#     equations: 220/450 batch...
#     equations: 240/450 batch...
#     equations: 260/450 batch...
#     equations: 280/450 batch...
#     equations: 300/450 batch...
#     equations: 320/450 batch...
#     equations: 340/450 batch...
#     equations: 360/450 batch...
#     equations: 380/450 batch...
#     equations: 400/450 batch...
#     equations: 420/450 batch...
#     equations: 440/450 batch...
#   4317/4497 reaction có EQUATION parse được
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Graph: 3050 nodes, 18848 edges
#   G_pro: 3129 nodes (79 pathway), 24655 edges
#
# STEP 2 — Build eval sets
# Parsing HMDB (~10-20 phút, cần quét lại để lấy thêm field kegg_id)...
#   Done in 4.9 phut, 217920 metabolite
#   CTD parsed in 18.9s
#   Parsed 1090 markers in 0.5s
#   Extracting SMPDB metabolites...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:39<00:00, 1223.77it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   eval_set1 (HMDB+CTD): 305 diseases
#   eval_set2 (MarkerDB): 25 diseases
#   eval_set3 (SMPDB):    181 diseases
#   HMDB+CTD: 305 tên bệnh → 305 seed-set độc lập
#   MarkerDB: 25 tên bệnh → 25 seed-set độc lập
#   SMPDB: 181 tên bệnh → 50 seed-set độc lập
#
# STEP 3 — Eigendecomposition
#   eigh(3129×3129)...
#   Done in 9.5s
#   eigh(3050×3050)...
#   Done in 11.4s
#   Done.
#
# ============================================================
# [Table 1] RWR vs CTQW on G_cc (KEGG)...
# RWR/HMDB+CTD: 100% 305/305 [08:18<00:00,  1.63s/it]
# MetaboRank-lite/HMDB+CTD: 100% 305/305 [08:17<00:00,  1.63s/it]
# CTQW/HMDB+CTD: 100% 305/305 [03:33<00:00,  1.43it/s]
#   HMDB+CTD: 20.2 min
# RWR/MarkerDB: 100% 25/25 [00:55<00:00,  2.20s/it]
# MetaboRank-lite/MarkerDB: 100% 25/25 [00:56<00:00,  2.26s/it]
# CTQW/MarkerDB: 100% 25/25 [00:24<00:00,  1.02it/s]
#   MarkerDB: 2.3 min
# RWR/SMPDB: 100% 181/181 [04:24<00:00,  1.46s/it]
# MetaboRank-lite/SMPDB: 100% 181/181 [04:19<00:00,  1.44s/it]
# CTQW/SMPDB: 100% 181/181 [01:55<00:00,  1.57it/s]
#   SMPDB: 10.7 min
#
# [Table 2] PROFANCY vs CTQW-PRO on G_pro (KEGG)...
# PROFANCY/HMDB+CTD: 100% 305/305 [08:22<00:00,  1.65s/it]
# MetaboRank-lite-PRO/HMDB+CTD: 100% 305/305 [08:23<00:00,  1.65s/it]
# CTQW-PRO/HMDB+CTD: 100% 305/305 [03:42<00:00,  1.37it/s]
#   HMDB+CTD: 20.5 min
# PROFANCY/MarkerDB: 100% 25/25 [00:59<00:00,  2.39s/it]
# MetaboRank-lite-PRO/MarkerDB: 100% 25/25 [01:00<00:00,  2.41s/it]
# CTQW-PRO/MarkerDB: 100% 25/25 [00:26<00:00,  1.05s/it]
#   MarkerDB: 2.4 min
# PROFANCY/SMPDB: 100% 181/181 [04:28<00:00,  1.48s/it]
# MetaboRank-lite-PRO/SMPDB: 100% 181/181 [04:26<00:00,  1.47s/it]
# CTQW-PRO/SMPDB: 100% 181/181 [02:03<00:00,  1.47it/s]
#   SMPDB: 11.0 min
#
# [Table 3] NH-CTQW-PRO (KEGG)...
#   Building NH eigendecomp (γ=16.0)... 133.4s
# NH/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.37it/s]
#   HMDB+CTD: 3.7 min
# NH/MarkerDB: 100% 25/25 [00:25<00:00,  1.01s/it]
#   MarkerDB: 0.4 min
# NH/SMPDB: 100% 181/181 [02:02<00:00,  1.48it/s]
#   SMPDB: 2.0 min
#
# ========================================================================
# TABLE 1: RWR vs MetaboRank-lite vs CTQW (G_cc, KEGG)
#
# === HMDB+CTD (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.7741   0.0092  0.0010  0.0113  0.0373
# MetaboRank-lite          0.7586   0.0176  0.0199  0.0352  0.0678 ◄
# CTQW                     0.7244   0.0230  0.0280  0.0461  0.0749 ◄
#
# === HMDB+CTD (dedup) (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.7741   0.0092  0.0010  0.0113  0.0373
# MetaboRank-lite          0.7586   0.0176  0.0199  0.0352  0.0678 ◄
# CTQW                     0.7244   0.0230  0.0280  0.0461  0.0749 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.8482   0.0145  0.0000  0.0170  0.0843
# MetaboRank-lite          0.8454   0.0339  0.0478  0.0823  0.1414 ◄
# CTQW                     0.8027   0.0534  0.0515  0.1097  0.1749 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.8482   0.0145  0.0000  0.0170  0.0843
# MetaboRank-lite          0.8454   0.0339  0.0478  0.0823  0.1414 ◄
# CTQW                     0.8027   0.0534  0.0515  0.1097  0.1749 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.9523   0.0545  0.0468  0.1200  0.3956
# MetaboRank-lite          0.9485   0.1667  0.2495  0.3722  0.4635 ◄
# CTQW                     0.9365   0.1962  0.2850  0.4158  0.5349 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# RWR                      0.9520   0.0566  0.0491  0.1443  0.4034
# MetaboRank-lite          0.9481   0.1727  0.2443  0.3492  0.4515 ◄
# CTQW                     0.9328   0.2148  0.3040  0.4205  0.5345 ◄
#
# ========================================================================
# TABLE 2: PROFANCY vs MetaboRank-lite-PRO vs CTQW-PRO (G_pro, KEGG)
#
# === HMDB+CTD (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8113   0.0096  0.0007  0.0114  0.0369
# MetaboRank-lite-PRO      0.8063   0.0190  0.0210  0.0358  0.0700 ◄
# t=0.1                    0.7729   0.0254  0.0274  0.0475  0.0774 ◄
#
# === HMDB+CTD (dedup) (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8113   0.0096  0.0007  0.0114  0.0369
# MetaboRank-lite-PRO      0.8063   0.0190  0.0210  0.0358  0.0700 ◄
# t=0.1                    0.7729   0.0254  0.0274  0.0475  0.0774 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8538   0.0159  0.0050  0.0170  0.0793
# MetaboRank-lite-PRO      0.8516   0.0353  0.0443  0.0864  0.1420 ◄
# t=0.1                    0.8253   0.0537  0.0570  0.1173  0.1828 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8538   0.0159  0.0050  0.0170  0.0793
# MetaboRank-lite-PRO      0.8516   0.0353  0.0443  0.0864  0.1420 ◄
# t=0.1                    0.8253   0.0537  0.0570  0.1173  0.1828 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9559   0.0549  0.0468  0.1216  0.3940
# MetaboRank-lite-PRO      0.9534   0.1657  0.2528  0.3707  0.4675 ◄
# t=0.1                    0.9497   0.1900  0.2631  0.4066  0.5544 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9554   0.0562  0.0491  0.1442  0.4025
# MetaboRank-lite-PRO      0.9529   0.1693  0.2463  0.3431  0.4511 ◄
# t=0.1                    0.9433   0.2072  0.2964  0.4114  0.5569 ◄
#
# ========================================================================
# TABLE 3: CTQW-PRO vs NH-CTQW-PRO (G_pro, KEGG)
#
# === HMDB+CTD (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.7729   0.0254  0.0274  0.0475  0.0774
# NH γ=16.0                0.7882   0.0285  0.0344  0.0568  0.0873 ◄
#
# === HMDB+CTD (dedup) (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.7729   0.0254  0.0274  0.0475  0.0774
# NH γ=16.0                0.7882   0.0285  0.0344  0.0568  0.0873 ◄
#
# === MarkerDB (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8253   0.0537  0.0570  0.1173  0.1828
# NH γ=16.0                0.8321   0.0571  0.0656  0.1310  0.2066 ◄
#
# === MarkerDB (dedup) (n=25) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.8253   0.0537  0.0570  0.1173  0.1828
# NH γ=16.0                0.8321   0.0571  0.0656  0.1310  0.2066 ◄
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9497   0.1900  0.2631  0.4066  0.5544
# NH γ=16.0                0.9520   0.2354  0.3260  0.4760  0.6050 ◄
#
# === SMPDB (dedup) (n=50) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# CTQW-PRO                 0.9433   0.2072  0.2964  0.4114  0.5569
# NH γ=16.0                0.9476   0.2501  0.3441  0.4601  0.5921 ◄
#
# ========================================================================
# WILCOXON: CTQW vs RWR
#
# --- HMDB+CTD (n=305) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.7741+/-0.0919   0.7244+/-0.1098  -0.0496  1.133e-32  ***
#   mrr        0.0092+/-0.0090   0.0230+/-0.0437  +0.0138  9.484e-09  ***
#   r@5        0.0010+/-0.0090   0.0280+/-0.0700  +0.0270    9.1e-12  ***
#   r@10       0.0113+/-0.0345   0.0461+/-0.1010  +0.0348   6.65e-12  ***
#   r@20       0.0373+/-0.0805   0.0749+/-0.1266  +0.0376  5.088e-13  ***
#
# --- MarkerDB (n=25) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.8482+/-0.0805   0.8027+/-0.1058  -0.0456  0.0001907  ***
#   mrr        0.0145+/-0.0083   0.0534+/-0.0580  +0.0389  9.835e-06  ***
#   r@5        0.0000+/-0.0000   0.0515+/-0.0629  +0.0515   0.004795  **
#   r@10       0.0170+/-0.0396   0.1097+/-0.1023  +0.0927  0.0009617  ***
#   r@20       0.0843+/-0.0843   0.1749+/-0.1316  +0.0906  0.0006581  ***
#
# --- SMPDB (n=181) ---
#   Metric                RWR             CTQW    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9365+/-0.0354  -0.0159  6.536e-25  ***
#   mrr        0.0545+/-0.0435   0.1962+/-0.1223  +0.1417  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.2850+/-0.1969  +0.2382  8.686e-30  ***
#   r@10       0.1200+/-0.1495   0.4158+/-0.1761  +0.2958  2.698e-29  ***
#   r@20       0.3956+/-0.1618   0.5349+/-0.1561  +0.1393      2e-23  ***
#
# WILCOXON: CTQW-PRO vs PROFANCY
#
# --- HMDB+CTD (n=305) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7729+/-0.0926  -0.0384    1.2e-26  ***
#   mrr        0.0096+/-0.0090   0.0254+/-0.0501  +0.0158  3.553e-12  ***
#   r@5        0.0007+/-0.0077   0.0274+/-0.0725  +0.0267   1.75e-11  ***
#   r@10       0.0114+/-0.0347   0.0475+/-0.1012  +0.0361  3.887e-12  ***
#   r@20       0.0369+/-0.0807   0.0774+/-0.1284  +0.0405   1.59e-13  ***
#
# --- MarkerDB (n=25) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8253+/-0.0972  -0.0284   0.005136  **
#   mrr        0.0159+/-0.0107   0.0537+/-0.0567  +0.0378  2.086e-05  ***
#   r@5        0.0050+/-0.0245   0.0570+/-0.0728  +0.0520    0.01087  *
#   r@10       0.0170+/-0.0396   0.1173+/-0.1300  +0.1003   0.000977  ***
#   r@20       0.0793+/-0.0854   0.1828+/-0.1571  +0.1035   0.002407  **
#
# --- SMPDB (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9497+/-0.0339  -0.0062  0.0008741  ***
#   mrr        0.0549+/-0.0462   0.1900+/-0.1129  +0.1351  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.2631+/-0.1786  +0.2163  7.866e-28  ***
#   r@10       0.1216+/-0.1486   0.4066+/-0.1697  +0.2849  2.655e-29  ***
#   r@20       0.3940+/-0.1654   0.5544+/-0.1439  +0.1604  1.047e-26  ***
#
# WILCOXON: MetaboRank-lite vs RWR (G_cc)
#
# --- HMDB+CTD (n=305) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.7741+/-0.0919   0.7586+/-0.0984  -0.0155  2.424e-38  ***
#   mrr        0.0092+/-0.0090   0.0176+/-0.0284  +0.0084  4.561e-17  ***
#   r@5        0.0010+/-0.0090   0.0199+/-0.0528  +0.0189  4.973e-11  ***
#   r@10       0.0113+/-0.0345   0.0352+/-0.0762  +0.0239  1.424e-10  ***
#   r@20       0.0373+/-0.0805   0.0678+/-0.1139  +0.0305  6.285e-12  ***
#
# --- MarkerDB (n=25) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.8482+/-0.0805   0.8454+/-0.0807  -0.0028     0.3549  ns
#   mrr        0.0145+/-0.0083   0.0339+/-0.0324  +0.0193   0.001882  **
#   r@5        0.0000+/-0.0000   0.0478+/-0.0728  +0.0478    0.01673  *
#   r@10       0.0170+/-0.0396   0.0823+/-0.0866  +0.0653    0.01572  *
#   r@20       0.0843+/-0.0843   0.1414+/-0.1262  +0.0571    0.07492  .
#
# --- SMPDB (n=181) ---
#   Metric                RWR  MetaboRank-lite    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9485+/-0.0287  -0.0039  5.108e-18  ***
#   mrr        0.0545+/-0.0435   0.1667+/-0.0885  +0.1122  1.953e-29  ***
#   r@5        0.0468+/-0.1000   0.2495+/-0.1226  +0.2027  2.418e-26  ***
#   r@10       0.1200+/-0.1495   0.3722+/-0.1577  +0.2522  3.195e-25  ***
#   r@20       0.3956+/-0.1618   0.4635+/-0.1748  +0.0679  3.009e-06  ***
#
# WILCOXON: CTQW vs MetaboRank-lite (G_cc)
#
# --- HMDB+CTD (n=305) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.7586+/-0.0984   0.7244+/-0.1098  -0.0341  1.361e-19  ***
#   mrr        0.0176+/-0.0284   0.0230+/-0.0437  +0.0054          1  ns
#   r@5        0.0199+/-0.0528   0.0280+/-0.0700  +0.0081     0.1981  ns
#   r@10       0.0352+/-0.0762   0.0461+/-0.1010  +0.0109    0.08708  .
#   r@20       0.0678+/-0.1139   0.0749+/-0.1266  +0.0071     0.9912  ns
#
# --- MarkerDB (n=25) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.8454+/-0.0807   0.8027+/-0.1058  -0.0427  0.0004402  ***
#   mrr        0.0339+/-0.0324   0.0534+/-0.0580  +0.0195          1  ns
#   r@5        0.0478+/-0.0728   0.0515+/-0.0629  +0.0037          1  ns
#   r@10       0.0823+/-0.0866   0.1097+/-0.1023  +0.0274     0.6026  ns
#   r@20       0.1414+/-0.1262   0.1749+/-0.1316  +0.0335          1  ns
#
# --- SMPDB (n=181) ---
#   Metric    MetaboRank-lite             CTQW    Delta     p_bonf  Sig
#   auc        0.9485+/-0.0287   0.9365+/-0.0354  -0.0120  2.589e-15  ***
#   mrr        0.1667+/-0.0885   0.1962+/-0.1223  +0.0295     0.2416  ns
#   r@5        0.2495+/-0.1226   0.2850+/-0.1969  +0.0355          1  ns
#   r@10       0.3722+/-0.1577   0.4158+/-0.1761  +0.0436     0.1224  ns
#   r@20       0.4635+/-0.1748   0.5349+/-0.1561  +0.0714  2.863e-05  ***
#
# WILCOXON: MetaboRank-lite-PRO vs PROFANCY (G_pro)
#
# --- HMDB+CTD (n=305) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.8063+/-0.0862  -0.0050  1.332e-12  ***
#   mrr        0.0096+/-0.0090   0.0190+/-0.0307  +0.0093  7.641e-21  ***
#   r@5        0.0007+/-0.0077   0.0210+/-0.0526  +0.0203  1.934e-12  ***
#   r@10       0.0114+/-0.0347   0.0358+/-0.0768  +0.0243  1.839e-10  ***
#   r@20       0.0369+/-0.0807   0.0700+/-0.1158  +0.0331   4.03e-13  ***
#
# --- MarkerDB (n=25) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8516+/-0.0836  -0.0022     0.8225  ns
#   mrr        0.0159+/-0.0107   0.0353+/-0.0338  +0.0194   0.002148  **
#   r@5        0.0050+/-0.0245   0.0443+/-0.0618  +0.0393    0.09211  .
#   r@10       0.0170+/-0.0396   0.0864+/-0.0986  +0.0694    0.01714  *
#   r@20       0.0793+/-0.0854   0.1420+/-0.1176  +0.0627    0.01079  *
#
# --- SMPDB (n=181) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9534+/-0.0254  -0.0025  2.067e-11  ***
#   mrr        0.0549+/-0.0462   0.1657+/-0.0905  +0.1109  1.158e-29  ***
#   r@5        0.0468+/-0.1000   0.2528+/-0.1314  +0.2060  2.547e-26  ***
#   r@10       0.1216+/-0.1486   0.3707+/-0.1628  +0.2491  3.075e-25  ***
#   r@20       0.3940+/-0.1654   0.4675+/-0.1754  +0.0735  2.932e-06  ***
#
# WILCOXON: CTQW-PRO vs MetaboRank-lite-PRO (G_pro)
#
# --- HMDB+CTD (n=305) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8063+/-0.0862   0.7729+/-0.0926  -0.0333  1.031e-21  ***
#   mrr        0.0190+/-0.0307   0.0254+/-0.0501  +0.0065     0.7955  ns
#   r@5        0.0210+/-0.0526   0.0274+/-0.0725  +0.0064     0.9412  ns
#   r@10       0.0358+/-0.0768   0.0475+/-0.1012  +0.0117     0.1733  ns
#   r@20       0.0700+/-0.1158   0.0774+/-0.1284  +0.0074          1  ns
#
# --- MarkerDB (n=25) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8516+/-0.0836   0.8253+/-0.0972  -0.0262    0.01128  *
#   mrr        0.0353+/-0.0338   0.0537+/-0.0567  +0.0183     0.7046  ns
#   r@5        0.0443+/-0.0618   0.0570+/-0.0728  +0.0127          1  ns
#   r@10       0.0864+/-0.0986   0.1173+/-0.1300  +0.0309     0.8933  ns
#   r@20       0.1420+/-0.1176   0.1828+/-0.1571  +0.0408     0.5814  ns
#
# --- SMPDB (n=181) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9534+/-0.0254   0.9497+/-0.0339  -0.0037          1  ns
#   mrr        0.1657+/-0.0905   0.1900+/-0.1129  +0.0243     0.1522  ns
#   r@5        0.2528+/-0.1314   0.2631+/-0.1786  +0.0103          1  ns
#   r@10       0.3707+/-0.1628   0.4066+/-0.1697  +0.0359     0.2222  ns
#   r@20       0.4675+/-0.1754   0.5544+/-0.1439  +0.0869  4.842e-09  ***
#
# WILCOXON: NH vs CTQW-PRO
#
# --- HMDB+CTD (n=305) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.7729+/-0.0926   0.7882+/-0.0882  +0.0153   2.25e-31  ***
#   mrr        0.0254+/-0.0501   0.0285+/-0.0529  +0.0031  1.181e-35  ***
#   r@5        0.0274+/-0.0725   0.0344+/-0.0809  +0.0070  1.138e-05  ***
#   r@10       0.0475+/-0.1012   0.0568+/-0.1142  +0.0093  2.884e-06  ***
#   r@20       0.0774+/-0.1284   0.0873+/-0.1316  +0.0100  1.582e-07  ***
#
# --- MarkerDB (n=25) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.8253+/-0.0972   0.8321+/-0.0970  +0.0067    0.05255  .
#   mrr        0.0537+/-0.0567   0.0571+/-0.0562  +0.0034  1.281e-05  ***
#   r@5        0.0570+/-0.0728   0.0656+/-0.0744  +0.0086     0.2156  ns
#   r@10       0.1173+/-0.1300   0.1310+/-0.1248  +0.0137     0.2156  ns
#   r@20       0.1828+/-0.1571   0.2066+/-0.1535  +0.0237    0.05859  .
#
# --- SMPDB (n=181) ---
#   Metric           CTQW-PRO        NH γ=16.0    Delta     p_bonf  Sig
#   auc        0.9497+/-0.0339   0.9520+/-0.0340  +0.0023  2.543e-08  ***
#   mrr        0.1900+/-0.1129   0.2354+/-0.1389  +0.0453  2.184e-27  ***
#   r@5        0.2631+/-0.1786   0.3260+/-0.1988  +0.0629  5.684e-17  ***
#   r@10       0.4066+/-0.1697   0.4760+/-0.1806  +0.0695  5.768e-18  ***
#   r@20       0.5544+/-0.1439   0.6050+/-0.1373  +0.0506  1.545e-17  ***
#
# WILCOXON CHÉO ĐỒ THỊ: PROFANCY (Gpro) vs RWR (Gcc)
#
# --- HMDB+CTD (n=305) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.7741+/-0.0919   0.8113+/-0.0824  +0.0373  1.855e-34  ***
#   mrr        0.0092+/-0.0090   0.0096+/-0.0090  +0.0004  5.401e-17  ***
#   r@5        0.0010+/-0.0090   0.0007+/-0.0077  -0.0003          1  ns
#   r@10       0.0113+/-0.0345   0.0114+/-0.0347  +0.0001          1  ns
#   r@20       0.0373+/-0.0805   0.0369+/-0.0807  -0.0004          1  ns
#
# --- MarkerDB (n=25) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.8482+/-0.0805   0.8538+/-0.0838  +0.0055     0.7046  ns
#   mrr        0.0145+/-0.0083   0.0159+/-0.0107  +0.0014          1  ns
#   r@5        0.0000+/-0.0000   0.0050+/-0.0245  +0.0050          1  ns
# /usr/local/lib/python3.13/dist-packages/scipy/stats/_wilcoxon.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
#   r@10       0.0170+/-0.0396   0.0170+/-0.0396  +0.0000        nan
#   r@20       0.0843+/-0.0843   0.0793+/-0.0854  -0.0050          1  ns
#
# --- SMPDB (n=181) ---
#   Metric                RWR         PROFANCY    Delta     p_bonf  Sig
#   auc        0.9523+/-0.0273   0.9559+/-0.0239  +0.0035  9.602e-08  ***
#   mrr        0.0545+/-0.0435   0.0549+/-0.0462  +0.0004          1  ns
# /usr/local/lib/python3.13/dist-packages/scipy/stats/_wilcoxon.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
#   r@5        0.0468+/-0.1000   0.0468+/-0.1000  +0.0000        nan
#   r@10       0.1200+/-0.1495   0.1216+/-0.1486  +0.0016     0.8898  ns
#   r@20       0.3956+/-0.1618   0.3940+/-0.1654  -0.0016     0.6955  ns
#
# WILCOXON CHÉO ĐỒ THỊ: CTQW-PRO (Gpro) vs CTQW (Gcc)
#
# --- HMDB+CTD (n=305) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7244+/-0.1098   0.7729+/-0.0926  +0.0485  6.443e-40  ***
#   mrr        0.0230+/-0.0437   0.0254+/-0.0501  +0.0025  7.531e-10  ***
#   r@5        0.0280+/-0.0700   0.0274+/-0.0725  -0.0006          1  ns
#   r@10       0.0461+/-0.1010   0.0475+/-0.1012  +0.0014          1  ns
#   r@20       0.0749+/-0.1266   0.0774+/-0.1284  +0.0025          1  ns
#
# --- MarkerDB (n=25) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8027+/-0.1058   0.8253+/-0.0972  +0.0227   0.002782  **
#   mrr        0.0534+/-0.0580   0.0537+/-0.0567  +0.0003          1  ns
#   r@5        0.0515+/-0.0629   0.0570+/-0.0728  +0.0055          1  ns
#   r@10       0.1097+/-0.1023   0.1173+/-0.1300  +0.0076          1  ns
#   r@20       0.1749+/-0.1316   0.1828+/-0.1571  +0.0079          1  ns
#
# --- SMPDB (n=181) ---
#   Metric               CTQW         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9365+/-0.0354   0.9497+/-0.0339  +0.0132  1.646e-17  ***
#   mrr        0.1962+/-0.1223   0.1900+/-0.1129  -0.0062          1  ns
#   r@5        0.2850+/-0.1969   0.2631+/-0.1786  -0.0220  0.0007177  ***
#   r@10       0.4158+/-0.1761   0.4066+/-0.1697  -0.0093      0.656  ns
#   r@20       0.5349+/-0.1561   0.5544+/-0.1439  +0.0195  3.702e-08  ***
#
# WILCOXON CHÉO ĐỒ THỊ: MetaboRank-lite-PRO (Gpro) vs MetaboRank-lite (Gcc)
#
# --- HMDB+CTD (n=305) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.7586+/-0.0984   0.8063+/-0.0862  +0.0477  1.133e-38  ***
#   mrr        0.0176+/-0.0284   0.0190+/-0.0307  +0.0014  1.123e-24  ***
#   r@5        0.0199+/-0.0528   0.0210+/-0.0526  +0.0011     0.4175  ns
#   r@10       0.0352+/-0.0762   0.0358+/-0.0768  +0.0006          1  ns
#   r@20       0.0678+/-0.1139   0.0700+/-0.1158  +0.0022     0.2989  ns
#
# --- MarkerDB (n=25) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8454+/-0.0807   0.8516+/-0.0836  +0.0062    0.09372  .
#   mrr        0.0339+/-0.0324   0.0353+/-0.0338  +0.0015    0.05255  .
#   r@5        0.0478+/-0.0728   0.0443+/-0.0618  -0.0035          1  ns
#   r@10       0.0823+/-0.0866   0.0864+/-0.0986  +0.0041          1  ns
#   r@20       0.1414+/-0.1262   0.1420+/-0.1176  +0.0006          1  ns
#
# --- SMPDB (n=181) ---
#   Metric    MetaboRank-lite MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9485+/-0.0287   0.9534+/-0.0254  +0.0049  2.473e-13  ***
#   mrr        0.1667+/-0.0885   0.1657+/-0.0905  -0.0009          1  ns
#   r@5        0.2495+/-0.1226   0.2528+/-0.1314  +0.0033    0.07253  .
#   r@10       0.3722+/-0.1577   0.3707+/-0.1628  -0.0015          1  ns
#   r@20       0.4635+/-0.1748   0.4675+/-0.1754  +0.0039     0.4718  ns
#
# --- Bootstrap 95% CI ---
#
#   AUC:
#     HMDB+CTD   PROFANCY             0.8113 [0.8021,0.8207]  n=305
#     MarkerDB   PROFANCY             0.8538 [0.8173,0.8855]  n=25
#     SMPDB      PROFANCY             0.9559 [0.9524,0.9594]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.8063 [0.7965,0.8160]  n=305
#     MarkerDB   MetaboRank-lite-PRO  0.8516 [0.8160,0.8832]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.9534 [0.9497,0.9571]  n=181
#     HMDB+CTD   CTQW-PRO             0.7729 [0.7627,0.7834]  n=305
#     MarkerDB   CTQW-PRO             0.8253 [0.7873,0.8633]  n=25
#     SMPDB      CTQW-PRO             0.9497 [0.9450,0.9547]  n=181
#     HMDB+CTD   NH γ=16.0            0.7882 [0.7785,0.7983]  n=305
#     MarkerDB   NH γ=16.0            0.8321 [0.7939,0.8696]  n=25
#     SMPDB      NH γ=16.0            0.9520 [0.9473,0.9568]  n=181
#
#   MRR:
#     HMDB+CTD   PROFANCY             0.0096 [0.0087,0.0107]  n=305
#     MarkerDB   PROFANCY             0.0159 [0.0120,0.0200]  n=25
#     SMPDB      PROFANCY             0.0549 [0.0490,0.0619]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.0190 [0.0158,0.0224]  n=305
#     MarkerDB   MetaboRank-lite-PRO  0.0353 [0.0231,0.0499]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.1657 [0.1540,0.1778]  n=181
#     HMDB+CTD   CTQW-PRO             0.0254 [0.0202,0.0314]  n=305
#     MarkerDB   CTQW-PRO             0.0537 [0.0341,0.0775]  n=25
#     SMPDB      CTQW-PRO             0.1900 [0.1741,0.2062]  n=181
#     HMDB+CTD   NH γ=16.0            0.0285 [0.0229,0.0348]  n=305
#     MarkerDB   NH γ=16.0            0.0571 [0.0378,0.0808]  n=25
#     SMPDB      NH γ=16.0            0.2354 [0.2163,0.2557]  n=181
#
#   R@20:
#     HMDB+CTD   PROFANCY             0.0369 [0.0285,0.0456]  n=305
#     MarkerDB   PROFANCY             0.0793 [0.0474,0.1131]  n=25
#     SMPDB      PROFANCY             0.3940 [0.3725,0.4180]  n=181
#     HMDB+CTD   MetaboRank-lite-PRO  0.0700 [0.0574,0.0821]  n=305
#     MarkerDB   MetaboRank-lite-PRO  0.1420 [0.0984,0.1928]  n=25
#     SMPDB      MetaboRank-lite-PRO  0.4675 [0.4421,0.4915]  n=181
#     HMDB+CTD   CTQW-PRO             0.0774 [0.0633,0.0924]  n=305
#     MarkerDB   CTQW-PRO             0.1828 [0.1194,0.2436]  n=25
#     SMPDB      CTQW-PRO             0.5544 [0.5341,0.5743]  n=181
#     HMDB+CTD   NH γ=16.0            0.0873 [0.0738,0.1022]  n=305
#     MarkerDB   NH γ=16.0            0.2066 [0.1469,0.2719]  n=25
#     SMPDB      NH γ=16.0            0.6050 [0.5849,0.6254]  n=181
#
# --- Win counts ---
#   Pair                         Dataset    Metric  A wins  B wins   tie     n
#   --------------------------------------------------------------------
#   CTQW vs RWR                  HMDB+CTD   auc         51     254     0   305
#   CTQW vs RWR                  MarkerDB   auc          4      21     0    25
#   CTQW vs RWR                  SMPDB      auc         27     154     0   181
#   CTQW vs RWR                  HMDB+CTD   mrr        173     132     0   305
#   CTQW vs RWR                  MarkerDB   mrr         22       3     0    25
#   CTQW vs RWR                  SMPDB      mrr        181       0     0   181
#   CTQW vs MetaboRank-lite      HMDB+CTD   auc         77     228     0   305
#   CTQW vs MetaboRank-lite      MarkerDB   auc          5      20     0    25
#   CTQW vs MetaboRank-lite      SMPDB      auc         42     139     0   181
#   CTQW vs MetaboRank-lite      HMDB+CTD   mrr        141     164     0   305
#   CTQW vs MetaboRank-lite      MarkerDB   mrr         14      11     0    25
#   CTQW vs MetaboRank-lite      SMPDB      mrr         90      91     0   181
#   CTQW-PRO vs PROFANCY         HMDB+CTD   auc         59     246     0   305
#   CTQW-PRO vs PROFANCY         MarkerDB   auc          8      17     0    25
#   CTQW-PRO vs PROFANCY         SMPDB      auc         72     109     0   181
#   CTQW-PRO vs PROFANCY         HMDB+CTD   mrr        190     115     0   305
#   CTQW-PRO vs PROFANCY         MarkerDB   mrr         22       3     0    25
#   CTQW-PRO vs PROFANCY         SMPDB      mrr        181       0     0   181
#   CTQW-PRO vs MetaboRank-lite-PRO HMDB+CTD   auc         66     239     0   305
#   CTQW-PRO vs MetaboRank-lite-PRO MarkerDB   auc          5      20     0    25
#   CTQW-PRO vs MetaboRank-lite-PRO SMPDB      auc        100      81     0   181
#   CTQW-PRO vs MetaboRank-lite-PRO HMDB+CTD   mrr        155     150     0   305
#   CTQW-PRO vs MetaboRank-lite-PRO MarkerDB   mrr         16       9     0    25
#   CTQW-PRO vs MetaboRank-lite-PRO SMPDB      mrr         99      82     0   181
#   NH γ=16.0 vs CTQW-PRO        HMDB+CTD   auc        251      54     0   305
#   NH γ=16.0 vs CTQW-PRO        MarkerDB   auc         19       6     0    25
#   NH γ=16.0 vs CTQW-PRO        SMPDB      auc        137      44     0   181
#   NH γ=16.0 vs CTQW-PRO        HMDB+CTD   mrr        273      32     0   305
#   NH γ=16.0 vs CTQW-PRO        MarkerDB   mrr         24       1     0    25
#   NH γ=16.0 vs CTQW-PRO        SMPDB      mrr        174       7     0   181

# %%
# !python /content/project/experiments/02_ablation_graph_kegg.py
# Out:
# Building graphs...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   G_pro: 3129 → clean: 3100 nodes
# Building eval sets...
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:44<00:00, 1103.62it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
# Eigendecomposition...
#   eigh(3100×3100)...
#   Done in 12.2s
#
# Running ablation...
# PROF_o/HMDB+CTD: 100% 305/305 [08:38<00:00,  1.70s/it]
# CTQW_o/HMDB+CTD: 100% 305/305 [03:49<00:00,  1.33it/s]
# PROF_c/HMDB+CTD: 100% 305/305 [08:34<00:00,  1.69s/it]
# CTQW_c/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
#   HMDB+CTD: 24.8 min
# PROF_o/MarkerDB: 100% 25/25 [01:00<00:00,  2.44s/it]
# CTQW_o/MarkerDB: 100% 25/25 [00:25<00:00,  1.04s/it]
# PROF_c/MarkerDB: 100% 25/25 [01:00<00:00,  2.41s/it]
# CTQW_c/MarkerDB: 100% 25/25 [00:26<00:00,  1.08s/it]
#   MarkerDB: 2.9 min
# PROF_o/SMPDB: 100% 181/181 [04:34<00:00,  1.52s/it]
# CTQW_o/SMPDB: 100% 181/181 [02:04<00:00,  1.46it/s]
# PROF_c/SMPDB: 100% 181/181 [04:51<00:00,  1.61s/it]
# CTQW_c/SMPDB: 100% 181/181 [02:02<00:00,  1.47it/s]
#   SMPDB: 13.5 min
#
# ========================================================================
# ABLATION: Original vs Clean G_pro_kegg
#
# === HMDB+CTD ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.8113     0.0096     0.8151     0.0227  +0.0131
# CTQW-PRO                   0.7729     0.0254     0.7987     0.0283  +0.0029
#
# === MarkerDB ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.8538     0.0159     0.8587     0.0437  +0.0278
# CTQW-PRO                   0.8253     0.0537     0.8423     0.0569  +0.0032
#
# === SMPDB ===
# Method                   AUC_orig   MRR_orig    AUC_cln    MRR_cln     ΔMRR
# ----------------------------------------------------------------------
# PROFANCY                   0.9559     0.0549     0.9543     0.2183  +0.1634
# CTQW-PRO                   0.9497     0.1900     0.9506     0.2023  +0.0123
#
# ========================================================================
# WILCOXON: gốc vs đã loại currency metabolite (ghép cặp theo bệnh)
#
# --- HMDB+CTD (n=305) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.8151+/-0.0878  +0.0038    0.04611  *
#   mrr        0.0096+/-0.0090   0.0227+/-0.0374  +0.0131  1.105e-49  ***
#   r@5        0.0007+/-0.0077   0.0233+/-0.0623  +0.0226  1.221e-13  ***
#   r@10       0.0114+/-0.0347   0.0450+/-0.0904  +0.0335  6.191e-18  ***
#   r@20       0.0369+/-0.0807   0.0727+/-0.1173  +0.0358  3.736e-18  ***
#
# --- HMDB+CTD (n=305) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.7729+/-0.0926   0.7987+/-0.0880  +0.0258   5.63e-13  ***
#   mrr        0.0254+/-0.0501   0.0283+/-0.0527  +0.0029  4.405e-06  ***
#   r@5        0.0274+/-0.0725   0.0339+/-0.0780  +0.0065  0.0008921  ***
#   r@10       0.0475+/-0.1012   0.0540+/-0.1077  +0.0065     0.0102  *
#   r@20       0.0774+/-0.1284   0.0822+/-0.1325  +0.0049     0.4896  ns
#
# --- MarkerDB (n=25) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.8538+/-0.0838   0.8587+/-0.0849  +0.0049          1  ns
#   mrr        0.0159+/-0.0107   0.0437+/-0.0430  +0.0278   5.96e-07  ***
#   r@5        0.0050+/-0.0245   0.0449+/-0.0689  +0.0399    0.01673  *
#   r@10       0.0170+/-0.0396   0.1026+/-0.0998  +0.0856    0.00146  **
#   r@20       0.0793+/-0.0854   0.1528+/-0.1130  +0.0735   0.002179  **
#
# --- MarkerDB (n=25) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.8253+/-0.0972   0.8423+/-0.0916  +0.0170    0.07361  .
#   mrr        0.0537+/-0.0567   0.0569+/-0.0546  +0.0032     0.4257  ns
#   r@5        0.0570+/-0.0728   0.0595+/-0.0634  +0.0025          1  ns
#   r@10       0.1173+/-0.1300   0.1331+/-0.1034  +0.0158     0.1152  ns
#   r@20       0.1828+/-0.1571   0.1913+/-0.1203  +0.0085          1  ns
#
# --- SMPDB (n=181) ---
#   Metric      PROFANCY_orig   PROFANCY_clean    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9543+/-0.0292  -0.0016     0.7918  ns
#   mrr        0.0549+/-0.0462   0.2183+/-0.1445  +0.1634  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.3229+/-0.1918  +0.2761  1.276e-29  ***
#   r@10       0.1216+/-0.1486   0.4427+/-0.2041  +0.3211  8.441e-29  ***
#   r@20       0.3940+/-0.1654   0.5617+/-0.1883  +0.1677  5.402e-27  ***
#
# --- SMPDB (n=181) ---
#   Metric      CTQW-PRO_orig   CTQW-PRO_clean    Delta     p_bonf  Sig
#   auc        0.9497+/-0.0339   0.9506+/-0.0297  +0.0009          1  ns
#   mrr        0.1900+/-0.1129   0.2023+/-0.1055  +0.0123  1.791e-08  ***
#   r@5        0.2631+/-0.1786   0.2807+/-0.1817  +0.0177    0.04029  *
#   r@10       0.4066+/-0.1697   0.4306+/-0.1874  +0.0241  9.422e-06  ***
#   r@20       0.5544+/-0.1439   0.6043+/-0.1586  +0.0500  2.781e-16  ***
#
# ========================================================================
# WIN-COUNT: gốc vs đã loại currency metabolite (ghép cặp theo bệnh, theo MRR)
# ========================================================================
# [HMDB+CTD] PROFANCY   loại thắng 293 | gốc thắng  12 | hoà   0 | tổng 305 bệnh (96.1% loại thắng)
# [HMDB+CTD] CTQW-PRO   loại thắng 192 | gốc thắng 113 | hoà   0 | tổng 305 bệnh (63.0% loại thắng)
# [MarkerDB] PROFANCY   loại thắng  24 | gốc thắng   1 | hoà   0 | tổng 25 bệnh (96.0% loại thắng)
# [MarkerDB] CTQW-PRO   loại thắng  16 | gốc thắng   9 | hoà   0 | tổng 25 bệnh (64.0% loại thắng)
# [SMPDB] PROFANCY   loại thắng 181 | gốc thắng   0 | hoà   0 | tổng 181 bệnh (100.0% loại thắng)
# [SMPDB] CTQW-PRO   loại thắng 118 | gốc thắng  63 | hoà   0 | tổng 181 bệnh (65.2% loại thắng)

# %%
# !python /content/project/experiments/05_supplementary_kegg.py
# Out:
# ── Supplementary S1 (KEGG): γ grid search ──
#   CSV not found — running experiment first...
# Setup pipeline (KEGG)...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:43<00:00, 1125.98it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   HMDB+CTD: 305, SMPDB: 181
# CTQW/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
# CTQW/SMPDB: 100% 181/181 [02:04<00:00,  1.45it/s]
#   γ=7... 131.5s
# NH(γ=7)/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
# NH(γ=7)/SMPDB: 100% 181/181 [02:02<00:00,  1.48it/s]
#   γ=11... 130.6s
# NH(γ=11)/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.37it/s]
# NH(γ=11)/SMPDB: 100% 181/181 [02:03<00:00,  1.46it/s]
#   γ=16... 133.8s
# NH(γ=16)/HMDB+CTD: 100% 305/305 [03:42<00:00,  1.37it/s]
# NH(γ=16)/SMPDB: 100% 181/181 [02:02<00:00,  1.47it/s]
#   γ=22... 133.9s
# NH(γ=22)/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.36it/s]
# NH(γ=22)/SMPDB: 100% 181/181 [02:03<00:00,  1.46it/s]
#   γ=29... 134.4s
# NH(γ=29)/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.36it/s]
# NH(γ=29)/SMPDB: 100% 181/181 [02:03<00:00,  1.47it/s]
#   γ=36... 131.5s
# NH(γ=36)/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.37it/s]
# NH(γ=36)/SMPDB: 100% 181/181 [02:02<00:00,  1.48it/s]
#   γ=44... 131.9s
# NH(γ=44)/HMDB+CTD: 100% 305/305 [03:40<00:00,  1.38it/s]
# NH(γ=44)/SMPDB: 100% 181/181 [02:01<00:00,  1.49it/s]
#   γ=58... 131.1s
# NH(γ=58)/HMDB+CTD: 100% 305/305 [03:45<00:00,  1.35it/s]
# NH(γ=58)/SMPDB: 100% 181/181 [02:02<00:00,  1.48it/s]
#   γ=109... 130.0s
# NH(γ=109)/HMDB+CTD: 100% 305/305 [03:42<00:00,  1.37it/s]
# NH(γ=109)/SMPDB: 100% 181/181 [02:02<00:00,  1.48it/s]
#   γ=254... 129.9s
# NH(γ=254)/HMDB+CTD: 100% 305/305 [03:43<00:00,  1.37it/s]
# NH(γ=254)/SMPDB: 100% 181/181 [02:01<00:00,  1.49it/s]
#
#   [HMDB+CTD]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.0254   (baseline, γ→∞)
#        7     0.0275
#       11     0.0281
#       16     0.0285  ← paper (γ=k̄)
#       22     0.0288
#       29     0.0289
#       36     0.0290
#       44     0.0291
#       58     0.0288
#      109     0.0286
#      254     0.0285
#
#   [SMPDB]       γ        MRR
#   ----------------------
#   CTQW-PRO     0.1900   (baseline, γ→∞)
#        7     0.2197
#       11     0.2275
#       16     0.2354  ← paper (γ=k̄)
#       22     0.2389
#       29     0.2397
#       36     0.2390
#       44     0.2380
#       58     0.2353
#      109     0.2302
#      254     0.2208
#
# ── Supplementary S2 (KEGG): t grid search ──
#   CSV not found — running experiment first...
# Setup pipeline (KEGG)...
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:45<00:00, 1080.23it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   HMDB+CTD: 305, SMPDB: 181
# CTQW-PRO(t=0.05)/HMDB+CTD: 100% 305/305 [03:49<00:00,  1.33it/s]
# CTQW-PRO(t=0.1)/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
# CTQW-PRO(t=0.2)/HMDB+CTD: 100% 305/305 [03:46<00:00,  1.35it/s]
# CTQW-PRO(t=0.5)/HMDB+CTD: 100% 305/305 [03:46<00:00,  1.35it/s]
# CTQW-PRO(t=0.8)/HMDB+CTD: 100% 305/305 [03:47<00:00,  1.34it/s]
#
#   [CTQW-PRO, HMDB+CTD]       t        MRR
#   ------------------------
#     0.05     0.0171
#      0.1     0.0254  ← selected
#      0.2     0.0247
#      0.5     0.0206
#      0.8     0.0159

# %%
# !python /content/project/experiments/06_compare_degree_bias_method_kegg.py
# Out:
# ==============================================================================
# SETUP (KEGG)
# ==============================================================================
#   [cache] 86 pathway, 4317 reaction (đã cache)
#   G_cc_kegg: 3050 compound (largest CC / 3061 tổng), 18848 cạnh
#   Disease pathways: 20248
# SMPDB files: 100% 48687/48687 [00:43<00:00, 1125.76it/s]
#   Loaded 20244 pathways (errors=0)
#   Dedup: 20243 → 3239 → 361 → 214
#   N = 3050, N_PRO = 3129
#   HMDB+CTD: 305 benh | SMPDB: 181 benh
#
# ==============================================================================
# PHAN A: chan doan coreness (KEGG)
# ==============================================================================
#   compute_coreness: 0.15s
#   29/29 currency metabolite trong G_pro
#   coreness toan mang: 2..26, TB 8.16
#
#   Nhom                         n   degree TB  coreness TB   (d-k) TB   k/d TB
#   Currency metabolite         29       402.3         23.6      378.7    0.212
#   Metabolite thuong         3021        10.5          7.7        2.9    0.882
#   Pathway node (ao)           79        73.5         20.5       53.1    0.350
#
#   Spearman(degree, coreness) tren node metabolite: rho = 0.9745 (p=0)
#
#   Trong so trung binh moi bien the gan cho tung nhom:
#   bien the         currency    thuong     ti le
#   core              23.5862    7.6855     3.07x   UU AI currency
#   diff               0.0198    0.6556     0.03x   PHAT currency
#   ratio              0.2117    0.8818     0.24x   PHAT currency
#
# ==============================================================================
# XAY DUNG PHUONG PHAP (KEGG)
# ==============================================================================
#   Dung NH-CTQW-PRO (gamma=16.0)... 130.2s
#   Thu tu bao cao: PROFANCY | DADA-EC | NetCore-core | NetCore-diff | NetCore-ratio | MetaboRank-lite-PRO | CTQW-PRO | NH-CTQW-PRO
#
# ==============================================================================
# PHAN B: danh gia LOO (KEGG)
# ==============================================================================
# PROFANCY/HMDB+CTD: 100% 305/305 [08:37<00:00,  1.70s/it]
#   HMDB+CTD | PROFANCY            : 8.6 min
# DADA-EC/HMDB+CTD: 100% 305/305 [08:24<00:00,  1.65s/it]
#   HMDB+CTD | DADA-EC             : 8.4 min
# NetCore-core/HMDB+CTD: 100% 305/305 [08:25<00:00,  1.66s/it]
#   HMDB+CTD | NetCore-core        : 8.4 min
# NetCore-diff/HMDB+CTD: 100% 305/305 [10:15<00:00,  2.02s/it]
#   HMDB+CTD | NetCore-diff        : 10.3 min
# NetCore-ratio/HMDB+CTD: 100% 305/305 [09:05<00:00,  1.79s/it]
#   HMDB+CTD | NetCore-ratio       : 9.1 min
# MetaboRank-lite-PRO/HMDB+CTD: 100% 305/305 [08:34<00:00,  1.69s/it]
#   HMDB+CTD | MetaboRank-lite-PRO : 8.6 min
# CTQW-PRO/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
#   HMDB+CTD | CTQW-PRO            : 3.7 min
# NH-CTQW-PRO/HMDB+CTD: 100% 305/305 [03:44<00:00,  1.36it/s]
#   HMDB+CTD | NH-CTQW-PRO         : 3.7 min
#
# === HMDB+CTD (n=305) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.8113   0.0096  0.0007  0.0114  0.0369
# DADA-EC                  0.7658   0.0104  0.0066  0.0165  0.0419 ◄
# NetCore-core             0.7974   0.0089  0.0003  0.0093  0.0343
# NetCore-diff             0.7533   0.0131  0.0101  0.0199  0.0458 ◄
# NetCore-ratio            0.7961   0.0198  0.0229  0.0393  0.0699 ◄
# MetaboRank-lite-PRO      0.8063   0.0190  0.0210  0.0358  0.0700 ◄
# CTQW-PRO                 0.7729   0.0254  0.0274  0.0475  0.0774 ◄
# NH-CTQW-PRO              0.7882   0.0285  0.0344  0.0568  0.0873 ◄
# PROFANCY/SMPDB: 100% 181/181 [04:34<00:00,  1.52s/it]
#   SMPDB | PROFANCY            : 4.6 min
# DADA-EC/SMPDB: 100% 181/181 [04:27<00:00,  1.48s/it]
#   SMPDB | DADA-EC             : 4.5 min
# NetCore-core/SMPDB: 100% 181/181 [04:32<00:00,  1.50s/it]
#   SMPDB | NetCore-core        : 4.5 min
# NetCore-diff/SMPDB: 100% 181/181 [05:31<00:00,  1.83s/it]
#   SMPDB | NetCore-diff        : 5.5 min
# NetCore-ratio/SMPDB: 100% 181/181 [04:38<00:00,  1.54s/it]
#   SMPDB | NetCore-ratio       : 4.6 min
# MetaboRank-lite-PRO/SMPDB: 100% 181/181 [04:35<00:00,  1.52s/it]
#   SMPDB | MetaboRank-lite-PRO : 4.6 min
# CTQW-PRO/SMPDB: 100% 181/181 [02:04<00:00,  1.45it/s]
#   SMPDB | CTQW-PRO            : 2.1 min
# NH-CTQW-PRO/SMPDB: 100% 181/181 [02:03<00:00,  1.47it/s]
#   SMPDB | NH-CTQW-PRO         : 2.1 min
#
# === SMPDB (n=181) ===
# Method                      AUC      MRR     R@5    R@10    R@20
# ---------------------------------------------------------
# PROFANCY                 0.9559   0.0549  0.0468  0.1216  0.3940
# DADA-EC                  0.9238   0.0664  0.0933  0.1857  0.2812 ◄
# NetCore-core             0.9556   0.0465  0.0342  0.0943  0.2998
# NetCore-diff             0.9234   0.1000  0.1463  0.2286  0.3090 ◄
# NetCore-ratio            0.9517   0.1785  0.2502  0.3617  0.4676 ◄
# MetaboRank-lite-PRO      0.9534   0.1657  0.2528  0.3707  0.4675 ◄
# CTQW-PRO                 0.9497   0.1900  0.2631  0.4066  0.5544 ◄
# NH-CTQW-PRO              0.9520   0.2354  0.3260  0.4760  0.6050 ◄
#
# ==============================================================================
# PHAN D: kiem dinh thong ke (KEGG)
# ==============================================================================
#
# ##############################################################################
# # HMDB+CTD: tung phuong phap vs PROFANCY
# ##############################################################################
#
# --- HMDB+CTD: DADA-EC vs PROFANCY (n=305) ---
#   Metric           PROFANCY          DADA-EC    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7658+/-0.1015  -0.0455  1.535e-41  ***
#   mrr        0.0096+/-0.0090   0.0104+/-0.0167  +0.0008     0.2355  ns
#   r@5        0.0007+/-0.0077   0.0066+/-0.0355  +0.0059   0.005966  **
#   r@10       0.0114+/-0.0347   0.0165+/-0.0562  +0.0050     0.1682  ns
#   r@20       0.0369+/-0.0807   0.0419+/-0.0878  +0.0050     0.6283  ns
#
# --- HMDB+CTD: NetCore-core vs PROFANCY (n=305) ---
#   Metric           PROFANCY     NetCore-core    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7974+/-0.0804  -0.0139  7.275e-17  ***
#   mrr        0.0096+/-0.0090   0.0089+/-0.0079  -0.0008   0.002051  **
#   r@5        0.0007+/-0.0077   0.0003+/-0.0043  -0.0004          1  ns
#   r@10       0.0114+/-0.0347   0.0093+/-0.0296  -0.0021     0.6918  ns
#   r@20       0.0369+/-0.0807   0.0343+/-0.0727  -0.0026          1  ns
#
# --- HMDB+CTD: NetCore-diff vs PROFANCY (n=305) ---
#   Metric           PROFANCY     NetCore-diff    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7533+/-0.1078  -0.0580  5.366e-40  ***
#   mrr        0.0096+/-0.0090   0.0131+/-0.0240  +0.0035          1  ns
#   r@5        0.0007+/-0.0077   0.0101+/-0.0408  +0.0094  1.286e-05  ***
#   r@10       0.0114+/-0.0347   0.0199+/-0.0534  +0.0085   0.006526  **
#   r@20       0.0369+/-0.0807   0.0458+/-0.0911  +0.0089     0.1045  ns
#
# --- HMDB+CTD: NetCore-ratio vs PROFANCY (n=305) ---
#   Metric           PROFANCY    NetCore-ratio    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7961+/-0.0945  -0.0152  1.329e-13  ***
#   mrr        0.0096+/-0.0090   0.0198+/-0.0325  +0.0102  1.744e-12  ***
#   r@5        0.0007+/-0.0077   0.0229+/-0.0555  +0.0222  4.689e-13  ***
#   r@10       0.0114+/-0.0347   0.0393+/-0.0815  +0.0279    2.4e-12  ***
#   r@20       0.0369+/-0.0807   0.0699+/-0.1132  +0.0330  1.375e-12  ***
#
# --- HMDB+CTD: MetaboRank-lite-PRO vs PROFANCY (n=305) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.8063+/-0.0862  -0.0050  1.332e-12  ***
#   mrr        0.0096+/-0.0090   0.0190+/-0.0307  +0.0093  7.641e-21  ***
#   r@5        0.0007+/-0.0077   0.0210+/-0.0526  +0.0203  1.934e-12  ***
#   r@10       0.0114+/-0.0347   0.0358+/-0.0768  +0.0243  1.839e-10  ***
#   r@20       0.0369+/-0.0807   0.0700+/-0.1158  +0.0331   4.03e-13  ***
#
# --- HMDB+CTD: CTQW-PRO vs PROFANCY (n=305) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7729+/-0.0926  -0.0384    1.2e-26  ***
#   mrr        0.0096+/-0.0090   0.0254+/-0.0501  +0.0158  3.553e-12  ***
#   r@5        0.0007+/-0.0077   0.0274+/-0.0725  +0.0267   1.75e-11  ***
#   r@10       0.0114+/-0.0347   0.0475+/-0.1012  +0.0361  3.887e-12  ***
#   r@20       0.0369+/-0.0807   0.0774+/-0.1284  +0.0405   1.59e-13  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs PROFANCY (n=305) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7882+/-0.0882  -0.0231  1.312e-15  ***
#   mrr        0.0096+/-0.0090   0.0285+/-0.0529  +0.0189  8.221e-20  ***
#   r@5        0.0007+/-0.0077   0.0344+/-0.0809  +0.0337  2.656e-14  ***
#   r@10       0.0114+/-0.0347   0.0568+/-0.1142  +0.0453  4.109e-15  ***
#   r@20       0.0369+/-0.0807   0.0873+/-0.1316  +0.0504  4.109e-18  ***
#
# ##############################################################################
# # HMDB+CTD: CTQW-PRO / NH-CTQW-PRO vs TUNG baseline
# ##############################################################################
#
# --- HMDB+CTD: CTQW-PRO vs PROFANCY (n=305) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7729+/-0.0926  -0.0384    1.2e-26  ***
#   mrr        0.0096+/-0.0090   0.0254+/-0.0501  +0.0158  3.553e-12  ***
#   r@5        0.0007+/-0.0077   0.0274+/-0.0725  +0.0267   1.75e-11  ***
#   r@10       0.0114+/-0.0347   0.0475+/-0.1012  +0.0361  3.887e-12  ***
#   r@20       0.0369+/-0.0807   0.0774+/-0.1284  +0.0405   1.59e-13  ***
#
# --- HMDB+CTD: CTQW-PRO vs DADA-EC (n=305) ---
#   Metric            DADA-EC         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7658+/-0.1015   0.7729+/-0.0926  +0.0071     0.2004  ns
#   mrr        0.0104+/-0.0167   0.0254+/-0.0501  +0.0151  9.349e-18  ***
#   r@5        0.0066+/-0.0355   0.0274+/-0.0725  +0.0208  5.448e-08  ***
#   r@10       0.0165+/-0.0562   0.0475+/-0.1012  +0.0310  8.224e-09  ***
#   r@20       0.0419+/-0.0878   0.0774+/-0.1284  +0.0355    1.1e-08  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-core (n=305) ---
#   Metric       NetCore-core         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7974+/-0.0804   0.7729+/-0.0926  -0.0245    2.7e-13  ***
#   mrr        0.0089+/-0.0079   0.0254+/-0.0501  +0.0166  3.595e-18  ***
#   r@5        0.0003+/-0.0043   0.0274+/-0.0725  +0.0271  1.751e-11  ***
#   r@10       0.0093+/-0.0296   0.0475+/-0.1012  +0.0382  2.937e-12  ***
#   r@20       0.0343+/-0.0727   0.0774+/-0.1284  +0.0430  1.044e-13  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-diff (n=305) ---
#   Metric       NetCore-diff         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7533+/-0.1078   0.7729+/-0.0926  +0.0196  6.536e-06  ***
#   mrr        0.0131+/-0.0240   0.0254+/-0.0501  +0.0123  7.702e-11  ***
#   r@5        0.0101+/-0.0408   0.0274+/-0.0725  +0.0173  1.166e-05  ***
#   r@10       0.0199+/-0.0534   0.0475+/-0.1012  +0.0276  1.244e-06  ***
#   r@20       0.0458+/-0.0911   0.0774+/-0.1284  +0.0316  5.088e-06  ***
#
# --- HMDB+CTD: CTQW-PRO vs NetCore-ratio (n=305) ---
#   Metric      NetCore-ratio         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7961+/-0.0945   0.7729+/-0.0926  -0.0232  9.842e-11  ***
#   mrr        0.0198+/-0.0325   0.0254+/-0.0501  +0.0057          1  ns
#   r@5        0.0229+/-0.0555   0.0274+/-0.0725  +0.0045          1  ns
#   r@10       0.0393+/-0.0815   0.0475+/-0.1012  +0.0082          1  ns
#   r@20       0.0699+/-0.1132   0.0774+/-0.1284  +0.0074          1  ns
#
# --- HMDB+CTD: CTQW-PRO vs MetaboRank-lite-PRO (n=305) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8063+/-0.0862   0.7729+/-0.0926  -0.0333  1.031e-21  ***
#   mrr        0.0190+/-0.0307   0.0254+/-0.0501  +0.0065     0.7955  ns
#   r@5        0.0210+/-0.0526   0.0274+/-0.0725  +0.0064     0.9412  ns
#   r@10       0.0358+/-0.0768   0.0475+/-0.1012  +0.0117     0.1733  ns
#   r@20       0.0700+/-0.1158   0.0774+/-0.1284  +0.0074          1  ns
#
# --- HMDB+CTD: NH-CTQW-PRO vs PROFANCY (n=305) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8113+/-0.0824   0.7882+/-0.0882  -0.0231  1.312e-15  ***
#   mrr        0.0096+/-0.0090   0.0285+/-0.0529  +0.0189  8.221e-20  ***
#   r@5        0.0007+/-0.0077   0.0344+/-0.0809  +0.0337  2.656e-14  ***
#   r@10       0.0114+/-0.0347   0.0568+/-0.1142  +0.0453  4.109e-15  ***
#   r@20       0.0369+/-0.0807   0.0873+/-0.1316  +0.0504  4.109e-18  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs DADA-EC (n=305) ---
#   Metric            DADA-EC      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7658+/-0.1015   0.7882+/-0.0882  +0.0224  2.253e-09  ***
#   mrr        0.0104+/-0.0167   0.0285+/-0.0529  +0.0181  1.614e-23  ***
#   r@5        0.0066+/-0.0355   0.0344+/-0.0809  +0.0278  8.263e-11  ***
#   r@10       0.0165+/-0.0562   0.0568+/-0.1142  +0.0403  3.321e-12  ***
#   r@20       0.0419+/-0.0878   0.0873+/-0.1316  +0.0454  3.969e-13  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-core (n=305) ---
#   Metric       NetCore-core      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7974+/-0.0804   0.7882+/-0.0882  -0.0092    0.00191  **
#   mrr        0.0089+/-0.0079   0.0285+/-0.0529  +0.0197  2.126e-24  ***
#   r@5        0.0003+/-0.0043   0.0344+/-0.0809  +0.0341  2.657e-14  ***
#   r@10       0.0093+/-0.0296   0.0568+/-0.1142  +0.0474   5.07e-15  ***
#   r@20       0.0343+/-0.0727   0.0873+/-0.1316  +0.0530  4.008e-18  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-diff (n=305) ---
#   Metric       NetCore-diff      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7533+/-0.1078   0.7882+/-0.0882  +0.0349  9.152e-17  ***
#   mrr        0.0131+/-0.0240   0.0285+/-0.0529  +0.0154  1.177e-16  ***
#   r@5        0.0101+/-0.0408   0.0344+/-0.0809  +0.0243  7.139e-09  ***
#   r@10       0.0199+/-0.0534   0.0568+/-0.1142  +0.0368  8.912e-11  ***
#   r@20       0.0458+/-0.0911   0.0873+/-0.1316  +0.0416  2.303e-10  ***
#
# --- HMDB+CTD: NH-CTQW-PRO vs NetCore-ratio (n=305) ---
#   Metric      NetCore-ratio      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.7961+/-0.0945   0.7882+/-0.0882  -0.0079    0.03743  *
#   mrr        0.0198+/-0.0325   0.0285+/-0.0529  +0.0087   0.000146  ***
#   r@5        0.0229+/-0.0555   0.0344+/-0.0809  +0.0115    0.03265  *
#   r@10       0.0393+/-0.0815   0.0568+/-0.1142  +0.0174    0.00441  **
#   r@20       0.0699+/-0.1132   0.0873+/-0.1316  +0.0174   0.005006  **
#
# --- HMDB+CTD: NH-CTQW-PRO vs MetaboRank-lite-PRO (n=305) ---
#   Metric   MetaboRank-lite-PRO      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.8063+/-0.0862   0.7882+/-0.0882  -0.0181  2.863e-10  ***
#   mrr        0.0190+/-0.0307   0.0285+/-0.0529  +0.0096  0.0002635  ***
#   r@5        0.0210+/-0.0526   0.0344+/-0.0809  +0.0134   0.008906  **
#   r@10       0.0358+/-0.0768   0.0568+/-0.1142  +0.0210  0.0001687  ***
#   r@20       0.0700+/-0.1158   0.0873+/-0.1316  +0.0173  0.0006328  ***
#
# ##############################################################################
# # SMPDB: tung phuong phap vs PROFANCY
# ##############################################################################
#
# --- SMPDB: DADA-EC vs PROFANCY (n=181) ---
#   Metric           PROFANCY          DADA-EC    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9238+/-0.0378  -0.0321  1.315e-28  ***
#   mrr        0.0549+/-0.0462   0.0664+/-0.0534  +0.0116   0.005438  **
#   r@5        0.0468+/-0.1000   0.0933+/-0.0971  +0.0465  1.362e-05  ***
#   r@10       0.1216+/-0.1486   0.1857+/-0.1358  +0.0641  9.416e-06  ***
#   r@20       0.3940+/-0.1654   0.2812+/-0.1608  -0.1128  1.018e-11  ***
#
# --- SMPDB: NetCore-core vs PROFANCY (n=181) ---
#   Metric           PROFANCY     NetCore-core    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9556+/-0.0253  -0.0003          1  ns
#   mrr        0.0549+/-0.0462   0.0465+/-0.0383  -0.0083  2.932e-29  ***
#   r@5        0.0468+/-0.1000   0.0342+/-0.0792  -0.0126  3.925e-05  ***
#   r@10       0.1216+/-0.1486   0.0943+/-0.1145  -0.0273   4.14e-10  ***
#   r@20       0.3940+/-0.1654   0.2998+/-0.1666  -0.0942  1.177e-19  ***
#
# --- SMPDB: NetCore-diff vs PROFANCY (n=181) ---
#   Metric           PROFANCY     NetCore-diff    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9234+/-0.0389  -0.0325  3.549e-24  ***
#   mrr        0.0549+/-0.0462   0.1000+/-0.0775  +0.0451  4.359e-12  ***
#   r@5        0.0468+/-0.1000   0.1463+/-0.1131  +0.0994  4.357e-15  ***
#   r@10       0.1216+/-0.1486   0.2286+/-0.1563  +0.1070  2.662e-10  ***
#   r@20       0.3940+/-0.1654   0.3090+/-0.1736  -0.0850  8.052e-06  ***
#
# --- SMPDB: NetCore-ratio vs PROFANCY (n=181) ---
#   Metric           PROFANCY    NetCore-ratio    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9517+/-0.0268  -0.0042   0.004723  **
#   mrr        0.0549+/-0.0462   0.1785+/-0.1044  +0.1236  8.628e-30  ***
#   r@5        0.0468+/-0.1000   0.2502+/-0.1383  +0.2034  3.611e-25  ***
#   r@10       0.1216+/-0.1486   0.3617+/-0.1768  +0.2400  2.631e-25  ***
#   r@20       0.3940+/-0.1654   0.4676+/-0.1917  +0.0736  5.529e-06  ***
#
# --- SMPDB: MetaboRank-lite-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY MetaboRank-lite-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9534+/-0.0254  -0.0025  2.067e-11  ***
#   mrr        0.0549+/-0.0462   0.1657+/-0.0905  +0.1109  1.158e-29  ***
#   r@5        0.0468+/-0.1000   0.2528+/-0.1314  +0.2060  2.547e-26  ***
#   r@10       0.1216+/-0.1486   0.3707+/-0.1628  +0.2491  3.075e-25  ***
#   r@20       0.3940+/-0.1654   0.4675+/-0.1754  +0.0735  2.932e-06  ***
#
# --- SMPDB: CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9497+/-0.0339  -0.0062  0.0008741  ***
#   mrr        0.0549+/-0.0462   0.1900+/-0.1129  +0.1351  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.2631+/-0.1786  +0.2163  7.866e-28  ***
#   r@10       0.1216+/-0.1486   0.4066+/-0.1697  +0.2849  2.655e-29  ***
#   r@20       0.3940+/-0.1654   0.5544+/-0.1439  +0.1604  1.047e-26  ***
#
# --- SMPDB: NH-CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9520+/-0.0340  -0.0038          1  ns
#   mrr        0.0549+/-0.0462   0.2354+/-0.1389  +0.1805  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.3260+/-0.1988  +0.2792   4.02e-30  ***
#   r@10       0.1216+/-0.1486   0.4760+/-0.1806  +0.3544  4.126e-30  ***
#   r@20       0.3940+/-0.1654   0.6050+/-0.1373  +0.2110  7.351e-28  ***
#
# ##############################################################################
# # SMPDB: CTQW-PRO / NH-CTQW-PRO vs TUNG baseline
# ##############################################################################
#
# --- SMPDB: CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9497+/-0.0339  -0.0062  0.0008741  ***
#   mrr        0.0549+/-0.0462   0.1900+/-0.1129  +0.1351  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.2631+/-0.1786  +0.2163  7.866e-28  ***
#   r@10       0.1216+/-0.1486   0.4066+/-0.1697  +0.2849  2.655e-29  ***
#   r@20       0.3940+/-0.1654   0.5544+/-0.1439  +0.1604  1.047e-26  ***
#
# --- SMPDB: CTQW-PRO vs DADA-EC (n=181) ---
#   Metric            DADA-EC         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9238+/-0.0378   0.9497+/-0.0339  +0.0259  1.219e-17  ***
#   mrr        0.0664+/-0.0534   0.1900+/-0.1129  +0.1236  6.127e-27  ***
#   r@5        0.0933+/-0.0971   0.2631+/-0.1786  +0.1697  7.968e-20  ***
#   r@10       0.1857+/-0.1358   0.4066+/-0.1697  +0.2208  3.872e-23  ***
#   r@20       0.2812+/-0.1608   0.5544+/-0.1439  +0.2732  3.239e-29  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-core (n=181) ---
#   Metric       NetCore-core         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9556+/-0.0253   0.9497+/-0.0339  -0.0059   0.003716  **
#   mrr        0.0465+/-0.0383   0.1900+/-0.1129  +0.1435  9.124e-31  ***
#   r@5        0.0342+/-0.0792   0.2631+/-0.1786  +0.2288  5.375e-28  ***
#   r@10       0.0943+/-0.1145   0.4066+/-0.1697  +0.3122  8.845e-31  ***
#   r@20       0.2998+/-0.1666   0.5544+/-0.1439  +0.2546  1.316e-29  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-diff (n=181) ---
#   Metric       NetCore-diff         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9234+/-0.0389   0.9497+/-0.0339  +0.0263  2.909e-15  ***
#   mrr        0.1000+/-0.0775   0.1900+/-0.1129  +0.0900  3.105e-13  ***
#   r@5        0.1463+/-0.1131   0.2631+/-0.1786  +0.1168  6.043e-11  ***
#   r@10       0.2286+/-0.1563   0.4066+/-0.1697  +0.1780  2.418e-19  ***
#   r@20       0.3090+/-0.1736   0.5544+/-0.1439  +0.2454  7.672e-26  ***
#
# --- SMPDB: CTQW-PRO vs NetCore-ratio (n=181) ---
#   Metric      NetCore-ratio         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9517+/-0.0268   0.9497+/-0.0339  -0.0020          1  ns
#   mrr        0.1785+/-0.1044   0.1900+/-0.1129  +0.0116          1  ns
#   r@5        0.2502+/-0.1383   0.2631+/-0.1786  +0.0128          1  ns
#   r@10       0.3617+/-0.1768   0.4066+/-0.1697  +0.0449     0.1862  ns
#   r@20       0.4676+/-0.1917   0.5544+/-0.1439  +0.0868  2.383e-07  ***
#
# --- SMPDB: CTQW-PRO vs MetaboRank-lite-PRO (n=181) ---
#   Metric   MetaboRank-lite-PRO         CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9534+/-0.0254   0.9497+/-0.0339  -0.0037          1  ns
#   mrr        0.1657+/-0.0905   0.1900+/-0.1129  +0.0243     0.1522  ns
#   r@5        0.2528+/-0.1314   0.2631+/-0.1786  +0.0103          1  ns
#   r@10       0.3707+/-0.1628   0.4066+/-0.1697  +0.0359     0.2222  ns
#   r@20       0.4675+/-0.1754   0.5544+/-0.1439  +0.0869  4.842e-09  ***
#
# --- SMPDB: NH-CTQW-PRO vs PROFANCY (n=181) ---
#   Metric           PROFANCY      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9559+/-0.0239   0.9520+/-0.0340  -0.0038          1  ns
#   mrr        0.0549+/-0.0462   0.2354+/-0.1389  +0.1805  9.124e-31  ***
#   r@5        0.0468+/-0.1000   0.3260+/-0.1988  +0.2792   4.02e-30  ***
#   r@10       0.1216+/-0.1486   0.4760+/-0.1806  +0.3544  4.126e-30  ***
#   r@20       0.3940+/-0.1654   0.6050+/-0.1373  +0.2110  7.351e-28  ***
#
# --- SMPDB: NH-CTQW-PRO vs DADA-EC (n=181) ---
#   Metric            DADA-EC      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9238+/-0.0378   0.9520+/-0.0340  +0.0283  2.421e-17  ***
#   mrr        0.0664+/-0.0534   0.2354+/-0.1389  +0.1689  3.921e-30  ***
#   r@5        0.0933+/-0.0971   0.3260+/-0.1988  +0.2327  1.438e-24  ***
#   r@10       0.1857+/-0.1358   0.4760+/-0.1806  +0.2903   1.35e-27  ***
#   r@20       0.2812+/-0.1608   0.6050+/-0.1373  +0.3238  1.956e-30  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-core (n=181) ---
#   Metric       NetCore-core      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9556+/-0.0253   0.9520+/-0.0340  -0.0035     0.7077  ns
#   mrr        0.0465+/-0.0383   0.2354+/-0.1389  +0.1888  9.124e-31  ***
#   r@5        0.0342+/-0.0792   0.3260+/-0.1988  +0.2918  2.757e-30  ***
#   r@10       0.0943+/-0.1145   0.4760+/-0.1806  +0.3817  9.113e-31  ***
#   r@20       0.2998+/-0.1666   0.6050+/-0.1373  +0.3052  8.705e-30  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-diff (n=181) ---
#   Metric       NetCore-diff      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9234+/-0.0389   0.9520+/-0.0340  +0.0286  8.786e-16  ***
#   mrr        0.1000+/-0.0775   0.2354+/-0.1389  +0.1354  1.964e-18  ***
#   r@5        0.1463+/-0.1131   0.3260+/-0.1988  +0.1797  5.251e-17  ***
#   r@10       0.2286+/-0.1563   0.4760+/-0.1806  +0.2475  5.592e-25  ***
#   r@20       0.3090+/-0.1736   0.6050+/-0.1373  +0.2960  1.146e-28  ***
#
# --- SMPDB: NH-CTQW-PRO vs NetCore-ratio (n=181) ---
#   Metric      NetCore-ratio      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9517+/-0.0268   0.9520+/-0.0340  +0.0004     0.2498  ns
#   mrr        0.1785+/-0.1044   0.2354+/-0.1389  +0.0569  2.999e-06  ***
#   r@5        0.2502+/-0.1383   0.3260+/-0.1988  +0.0758  0.0001149  ***
#   r@10       0.3617+/-0.1768   0.4760+/-0.1806  +0.1144  1.016e-10  ***
#   r@20       0.4676+/-0.1917   0.6050+/-0.1373  +0.1374   6.82e-18  ***
#
# --- SMPDB: NH-CTQW-PRO vs MetaboRank-lite-PRO (n=181) ---
#   Metric   MetaboRank-lite-PRO      NH-CTQW-PRO    Delta     p_bonf  Sig
#   auc        0.9534+/-0.0254   0.9520+/-0.0340  -0.0014     0.4622  ns
#   mrr        0.1657+/-0.0905   0.2354+/-0.1389  +0.0696  2.865e-08  ***
#   r@5        0.2528+/-0.1314   0.3260+/-0.1988  +0.0732  9.087e-05  ***
#   r@10       0.3707+/-0.1628   0.4760+/-0.1806  +0.1053  1.178e-10  ***
#   r@20       0.4675+/-0.1754   0.6050+/-0.1373  +0.1375  2.756e-19  ***
#
# ==============================================================================
# PHAN E: bang tong hop (KEGG)
# ==============================================================================
#
# === HMDB+CTD ===
# Phuong phap                AUC     MRR     R@5    R@10    R@20
# --------------------------------------------------------------
# PROFANCY                0.8113  0.0096  0.0007  0.0114  0.0369
# DADA-EC                 0.7658  0.0104  0.0066  0.0165  0.0419
# NetCore-core            0.7974  0.0089  0.0003  0.0093  0.0343
# NetCore-diff            0.7533  0.0131  0.0101  0.0199  0.0458
# NetCore-ratio           0.7961  0.0198  0.0229  0.0393  0.0699
# MetaboRank-lite-PRO     0.8063  0.0190  0.0210  0.0358  0.0700
# CTQW-PRO                0.7729  0.0254  0.0274  0.0475  0.0774
# NH-CTQW-PRO             0.7882  0.0285  0.0344  0.0568  0.0873
#   -> da luu kegg_E_bang_HMDBCTD.csv
#
# === SMPDB ===
# Phuong phap                AUC     MRR     R@5    R@10    R@20
# --------------------------------------------------------------
# PROFANCY                0.9559  0.0549  0.0468  0.1216  0.3940
# DADA-EC                 0.9238  0.0664  0.0933  0.1857  0.2812
# NetCore-core            0.9556  0.0465  0.0342  0.0943  0.2998
# NetCore-diff            0.9234  0.1000  0.1463  0.2286  0.3090
# NetCore-ratio           0.9517  0.1785  0.2502  0.3617  0.4676
# MetaboRank-lite-PRO     0.9534  0.1657  0.2528  0.3707  0.4675
# CTQW-PRO                0.9497  0.1900  0.2631  0.4066  0.5544
# NH-CTQW-PRO             0.9520  0.2354  0.3260  0.4760  0.6050
#   -> da luu kegg_E_bang_SMPDB.csv
#
# ==============================================================================
# XONG
# ==============================================================================
